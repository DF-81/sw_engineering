# %%
class KFZ:
    def __init__(self, hersteller, kennzeichen):
        self.hersteller = hersteller
        self.kennzeichen = kennzeichen

    def melde_um(self, neues_kennzeichen):
        self.kennzeichen = neues_kennzeichen
    
    def __repr__(self):
        return f"KFZ(hersteller='{self.hersteller}', kennzeichen='{self.kennzeichen}')"
    
    def __eq__(self, other):
        if not isinstance(other, KFZ):
            return False
        return self.hersteller == other.hersteller and self.kennzeichen == other.kennzeichen

# %%
# --- Create and compare KFZ-Instances ---

# now using __repr__ and __eq__ methods to compare and print the KFZ instances
print(repr(bmw))
print(repr(vw))
print(repr(bmw2))   

# Compare with __eq__ method, this is called with the == operator
print(f"bmw2 == bmw: {bmw2 == bmw}")
print(f"vw == bmw: {vw == bmw}")
print(f"vw == bmw2: {vw == bmw2}")
# Out:
# KFZ(hersteller='BMW', kennzeichen='F-B 21')
# KFZ(hersteller='VW', kennzeichen='BGL- A 9')
# KFZ(hersteller='BMW', kennzeichen='M-BW 123')
# bmw2 == bmw: False
# vw == bmw: False
# vw == bmw2: False
