# %%
# Teil 05 part 08 - Workshop: Begrüßung
# Schreiben Sie eine funktion drucke_begruessung(name), die eine personalisierte Begrüßung ausgibt, z.B.
# Hallo, Hans!
# Schön Sie heute wieder bei uns begrüßen zu dürfen.
# Wir wünschen Ihnen viel Spaß, Hans.
# Verwenden Sie dazu String-Interpolation.

# %%
def drucke_begruessung(name: str):
    ausgabe = f"Hallo, {name}!\nSchön Sie heute wieder bei uns begrüßen zu dürfen.\nWir wünschen Ihnen viel Spaß, {name}."
    print(ausgabe)

drucke_begruessung("Hans")

# %%
def drucke_begruessung(name: str):
    ausgabe = f"""Hallo, {name}!
    Schön Sie heute wieder bei uns begrüßen zu dürfen.
    Wir wünschen Ihnen viel Spaß, {name}."""

    print(ausgabe)

drucke_begruessung("Hans")
