# %%
# Teil 04 Part 2 - Workshop: Grundlegende Datentypen

# %%
# Wie können sie den String 'Hello, world' in Python darstellen?
"Hello, world"

# %%
# Wie können Sie den String Hello, World! auf dem Bildschirm ausgeben?
print("Hello, World!")

# %%
# Wie können Sie Ihren Namen als Text (String) in Python darstellen?
"Daniel Fechner"

# %%
# Wie können Sie die Zahl 123 in Python darstellen
123

# %%
# Wie können Sie ihren Namen auf dem Bildschirm ausgeben?
print("Daniel Fechner")

# %%
# Teil 04  Part 3 - Workshop: Zahlen und Mathematik

# %%
# Wie können Sie die den Datentyp von 14 in Python darstellen?
type(14)
# Out:
# int

# %%
# Wie können Sie den Datentyp von 14.0 in Python darstellen?
type(14.0)
# Out:
# float

# %%
# Wie können Sie den Datentyp von "14.0" in Python darstellen?
type("14.0")
# Out:
# str

# %%
# Was ist der Wert von 1 + 2 * 3
1+2*3 # 1+(2*3)
# Out:
# 7
